# %%
import pandas as pd

# %%
df_positive = pd.read_csv("./obrazy_good_3000.csv")
df_positive
# Out:
#       label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 0         0     109      93     110      67     107      86      73      86
# 1         0     109      88     105      67      96      88      82      80
# 2         0     108      78     111      68     101      86      81      88
# 3         0     255     255     255     255     255     255     255     255
# 4         0     255     255     255     255     255     255     255     255
# 5         0      90      69     106      56      86      84      92      84
# 6         0     108      93     108      84     101     110      67      86
# 7         0     104      86     121      61      93      88      84      83
# 8         0     109      93     109      66     106      88      73      87
# 9         0     109      87     122      61      98      90      76      80
# 10        0     105      96     123      74      93      97      87     107
# ...

# %%
df_good_100 = df_positive.iloc[:100]
df_good_500 = df_positive.iloc[:500]
df_good_1000 = df_positive.iloc[:1000]
df_good_2000 = df_positive.iloc[:2000]

# %%
df_good_100.to_csv("obrazy_good_100.csv")
df_good_500.to_csv("obrazy_good_500.csv")
df_good_1000.to_csv("obrazy_good_1000.csv")
df_good_2000.to_csv("obrazy_good_2000.csv")

# %%
df_negative = pd.read_csv("./obrazy_negatywne_duze_out.csv")
df_negative
# Out:
#       label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 0         1     159     116     134      90     103      94     106     111
# 1         1     117     109     107      81      99     132     129     131
# 2         1     161     116     125      89     108     103     107     112
# 3         1     184     142     164     126     132     128     131     147
# 4         1     151     125     132      83     107     101     109     107
# 5         1     157     123     132      82     108     102     109     105
# 6         1     184     142     164     126     132     128     131     147
# 7         1     151     124     132      83     107     100     109     106
# 8         1     146     120     124      87     105      97     102     108
# 9         1     111      88     106      64     103      87      98     104
# 10        1     151     125     132      83     107     100     108     107
# ...

# %%
df_bad_100 = df_negative.iloc[-100:]
df_bad_500 = df_negative.iloc[-500:]
df_bad_1000 = df_negative.iloc[-1000:]
df_bad_2000 = df_negative.iloc[-2000:]
df_bad_3000 = df_negative.iloc[-3000:]

# %%
df_bad_100.to_csv("obrazy_bad_100.csv")
df_bad_500.to_csv("obrazy_bad_500.csv")
df_bad_1000.to_csv("obrazy_bad_1000.csv")
df_bad_2000.to_csv("obrazy_bad_2000.csv")
df_bad_3000.to_csv("obrazy_bad_3000.csv")

# %%
df_concat_100 = pd.concat([df_good_100, df_bad_100])
df_concat_500 = pd.concat([df_good_500, df_bad_500])
df_concat_1000 = pd.concat([df_good_1000, df_bad_1000])
df_concat_2000 = pd.concat([df_good_2000, df_bad_2000])
df_concat_3000 = pd.concat([df_positive, df_bad_3000])

# %%
df_concat_100.to_csv("obrazy_concat_100.csv")
df_concat_500.to_csv("obrazy_concat_500.csv")
df_concat_1000.to_csv("obrazy_concat_1000.csv")
df_concat_2000.to_csv("obrazy_concat_2000.csv")
df_concat_3000.to_csv("obrazy_concat_3000.csv")
